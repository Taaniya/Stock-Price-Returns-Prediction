# %% [markdown]
# This notebook contains the logic of creating the feature set file - 'scaled_feature_set.csv'
# This file has all the features in normalised form while the target column is in raw form.

# %%
import technical_indicators as ti
import pandas as pd
import numpy as np
import lightgbm as lgb
from IPython.display import set_matplotlib_formats
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import RandomizedSearchCV
# %matplotlib inline

# %%
data = pd.read_csv("./AXISBANK.NS.csv")

# %%
data = pd.DataFrame(data.convert_objects(convert_numeric='float'))
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   """Entry point for launching an IPython kernel.

# %%
n1 = 30
n2 = 40
n3 = 50

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1232 entries, 0 to 1231
# Data columns (total 7 columns):
# Date         1232 non-null object
# Open         1232 non-null float64
# High         1232 non-null float64
# Low          1232 non-null float64
# Close        1232 non-null float64
# Adj Close    1232 non-null float64
# Volume       1232 non-null float64
# dtypes: float64(6), object(1)
# memory usage: 67.4+ KB

# %%
data.shape
# Out:
# (1232, 7)

# %%
data.ffill(inplace=True)

# %%
data.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2013-04-04  253.199997  254.000000  248.020004  248.770004  213.306046
# 1  2013-04-05  248.089996  249.869995  243.440002  245.910004  210.853775
# 2  2013-04-08  245.300003  247.600006  239.600006  240.639999  206.335022
# 3  2013-04-09  242.070007  247.960007  239.759995  240.639999  206.335022
# 4  2013-04-10  242.960007  248.570007  240.000000  247.860001  212.525757
#
#        Volume
# 0   6417705.0
# 1   6484050.0
# 2   4864420.0
# 3   7490495.0
# 4  10046765.0

# %%
dataset_indices = pd.to_datetime(data.Date, format='%Y-%m-%d')

# %%
data.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2013-04-04  253.199997  254.000000  248.020004  248.770004  213.306046
# 1  2013-04-05  248.089996  249.869995  243.440002  245.910004  210.853775
# 2  2013-04-08  245.300003  247.600006  239.600006  240.639999  206.335022
# 3  2013-04-09  242.070007  247.960007  239.759995  240.639999  206.335022
# 4  2013-04-10  242.960007  248.570007  240.000000  247.860001  212.525757
#
#        Volume
# 0   6417705.0
# 1   6484050.0
# 2   4864420.0
# 3   7490495.0
# 4  10046765.0

# %%
df = data
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2013-04-04  253.199997  254.000000  248.020004  248.770004  213.306046
# 1     2013-04-05  248.089996  249.869995  243.440002  245.910004  210.853775
# 2     2013-04-08  245.300003  247.600006  239.600006  240.639999  206.335022
# 3     2013-04-09  242.070007  247.960007  239.759995  240.639999  206.335022
# 4     2013-04-10  242.960007  248.570007  240.000000  247.860001  212.525757
# 5     2013-04-11  249.309998  250.979996  246.199997  250.429993  214.729401
# 6     2013-04-12  248.000000  255.399994  246.899994  252.860001  216.812988
# 7     2013-04-15  251.199997  262.269989  250.800003  258.839996  221.940491
# 8     2013-04-16  257.299988  273.799988  256.549988  272.660004  233.790359
# 9     2013-04-17  274.359985  290.000000  273.230011  275.440002  236.174042
# 10    2013-04-18  273.940002  287.380005  271.000000  285.880005  245.125748
# 11    2013-04-22  285.880005  296.799988  285.880005  288.230011  247.140747
# 12    2013-04-23  289.000000  291.019989  282.630005  288.959991  247.766663
# 13    2013-04-25  288.959991  304.000000  288.959991  300.679993  257.815857
# 14    2013-04-26  298.000000  299.980011  293.420013  297.269989  254.892029
# 15    2013-04-29  297.200012  297.200012  292.049988  295.079987  253.014206
# 16    2013-04-30  297.399994  300.200012  291.600006  298.540009  255.980957
# 1230  2018-04-03  494.000000  506.000000  493.700012  501.549988  501.549988
# 1231  2018-04-04  504.500000  504.500000  490.250000  492.250000  492.250000
#
#           Volume
# 0      6417705.0
# 1      6484050.0
# 2      4864420.0
# 3      7490495.0
# 4     10046765.0
# 5      9714180.0
# 6      7911225.0
# 7      7689700.0
# 8     11987860.0
# 9      9186545.0
# 10    11300880.0
# 11    13252895.0
# 12     7340650.0
# 13    19391755.0
# 14    10489965.0
# 15     6561785.0
# 16     9010945.0
# 17    10775590.0
# 18     9326475.0
# 19     6739100.0
# 20     7357170.0
# 21     4865505.0
# 22    15607600.0
# 23     7711835.0
# 24    10233900.0
# 25     6341930.0
# 26     8367595.0
# 27     5787370.0
# 28     6127865.0
# 29     7109685.0
# ...          ...
# 1202   4251723.0
# 1203   3395183.0
# 1204   4638382.0
# 1205   7808359.0
# 1206   3888629.0
# 1207   5297794.0
# 1208   4136383.0
# 1209   6626661.0
# 1210   9827510.0
# 1211   6766199.0
# 1212  12240120.0
# 1213  10428057.0
# 1214   8483978.0
# 1215   4955525.0
# 1216   5283334.0
# 1217   7846232.0
# 1218   4976540.0
# 1219   3932830.0
# 1220  12146623.0
# 1221   4656613.0
# 1222   5398111.0
# 1223   5518826.0
# 1224   7194256.0
# 1225  29385110.0
# 1226   9498614.0
# 1227   6423140.0
# 1228  10980960.0
# 1229   7120498.0
# 1230   6053789.0
# 1231   6047813.0
#
# [1232 rows x 7 columns]

# %% [markdown]
# #### Appending calculated Technical indicators columns

# %%
df11 = ti.moving_average(df,n1)
df12 = ti.moving_average(df11,n2)
df13 = ti.moving_average(df12,n3)

# %%
df13.head(1)
# Out:
#          Date        Open   High         Low       Close   Adj Close  \
# 0  2013-04-04  253.199997  254.0  248.020004  248.770004  213.306046
#
#       Volume  MA_30  MA_40  MA_50
# 0  6417705.0    NaN    NaN    NaN

# %%
df21 = ti.exponential_moving_average(df13,n1)
df22 = ti.exponential_moving_average(df21,n2)
df23 = ti.exponential_moving_average(df22,n3)

# %%
df23.head(1)
# Out:
#          Date        Open   High         Low       Close   Adj Close  \
# 0  2013-04-04  253.199997  254.0  248.020004  248.770004  213.306046
#
#       Volume  MA_30  MA_40  MA_50  EMA_30  EMA_40  EMA_50
# 0  6417705.0    NaN    NaN    NaN     NaN     NaN     NaN

# %%
df3 = ti.macd(df23,12,26)

# %%
df3.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2013-04-04  253.199997  254.000000  248.020004  248.770004  213.306046
# 1  2013-04-05  248.089996  249.869995  243.440002  245.910004  210.853775
# 2  2013-04-08  245.300003  247.600006  239.600006  240.639999  206.335022
# 3  2013-04-09  242.070007  247.960007  239.759995  240.639999  206.335022
# 4  2013-04-10  242.960007  248.570007  240.000000  247.860001  212.525757
#
#        Volume  MA_30  MA_40  MA_50  EMA_30  EMA_40  EMA_50  MACD_12_26  \
# 0   6417705.0    NaN    NaN    NaN     NaN     NaN     NaN         NaN
# 1   6484050.0    NaN    NaN    NaN     NaN     NaN     NaN         NaN
# 2   4864420.0    NaN    NaN    NaN     NaN     NaN     NaN         NaN
# 3   7490495.0    NaN    NaN    NaN     NaN     NaN     NaN         NaN
# 4  10046765.0    NaN    NaN    NaN     NaN     NaN     NaN         NaN
#
#    MACDsign_12_26  MACDdiff_12_26
# 0             NaN             NaN
# 1             NaN             NaN
# 2             NaN             NaN
# 3             NaN             NaN
# 4             NaN             NaN

# %%
df41 = ti.relative_strength_index(df3,n1)
df42 = ti.relative_strength_index(df41,n2)
df43 = ti.relative_strength_index(df42,n3)

# %%
df43.head(1)
# Out:
#          Date        Open   High         Low       Close   Adj Close  \
# 0  2013-04-04  253.199997  254.0  248.020004  248.770004  213.306046
#
#       Volume  MA_30  MA_40  MA_50  EMA_30  EMA_40  EMA_50  MACD_12_26  \
# 0  6417705.0    NaN    NaN    NaN     NaN     NaN     NaN         NaN
#
#    MACDsign_12_26  MACDdiff_12_26  RSI_30  RSI_40  RSI_50
# 0             NaN             NaN     NaN     NaN     NaN

# %%
df51 = ti.bollinger_bands(df43,n1)
df52 = ti.bollinger_bands(df51,n2)
df53 = ti.bollinger_bands(df52,n3)

# %%
df53.head(1)
# Out:
#          Date        Open   High         Low       Close   Adj Close  \
# 0  2013-04-04  253.199997  254.0  248.020004  248.770004  213.306046
#
#       Volume  MA_30  MA_40  MA_50       ...        MACDdiff_12_26  RSI_30  \
# 0  6417705.0    NaN    NaN    NaN       ...                   NaN     NaN
#
#    RSI_40  RSI_50  BollingerB_30  Bollinger%b_30  BollingerB_40  \
# 0     NaN     NaN            NaN             NaN            NaN
#
#    Bollinger%b_40  BollingerB_50  Bollinger%b_50
# 0             NaN            NaN             NaN
#
# [1 rows x 25 columns]

# %%
df61 = ti.stochastic_oscillator_d(df53,n1)
df62 = ti.stochastic_oscillator_d(df61,n2)
df63 = ti.stochastic_oscillator_d(df62,n3)

# %%
df63.head(1)
# Out:
#          Date        Open   High         Low       Close   Adj Close  \
# 0  2013-04-04  253.199997  254.0  248.020004  248.770004  213.306046
#
#       Volume  MA_30  MA_40  MA_50   ...     RSI_50  BollingerB_30  \
# 0  6417705.0    NaN    NaN    NaN   ...        NaN            NaN
#
#    Bollinger%b_30  BollingerB_40  Bollinger%b_40  BollingerB_50  \
# 0             NaN            NaN             NaN            NaN
#
#    Bollinger%b_50  SO%d_30  SO%d_40  SO%d_50
# 0             NaN      NaN      NaN      NaN
#
# [1 rows x 28 columns]

# %%
df7 = ti.stochastic_tor_k(df63)

# %%
df81 = ti.momentum(df7,n1)
df82 = ti.momentum(df81,n2)
df83 = ti.momentum(df82,n3)

# %%
df83.head(1)
# Out:
#          Date        Open   High         Low       Close   Adj Close  \
# 0  2013-04-04  253.199997  254.0  248.020004  248.770004  213.306046
#
#       Volume  MA_30  MA_40  MA_50     ...       Bollinger%b_40  BollingerB_50  \
# 0  6417705.0    NaN    NaN    NaN     ...                  NaN            NaN
#
#    Bollinger%b_50  SO%d_30  SO%d_40  SO%d_50      SO%k  Momentum_30  \
# 0             NaN      NaN      NaN      NaN  0.125418          NaN
#
#    Momentum_40  Momentum_50
# 0          NaN          NaN
#
# [1 rows x 32 columns]

# %%
df91 = ti.commodity_channel_index(df83,n1)
df92 = ti.commodity_channel_index(df91,n2)
df93 = ti.commodity_channel_index(df92,n3)

# %%
df93.head(1)
# Out:
#          Date        Open   High         Low       Close   Adj Close  \
# 0  2013-04-04  253.199997  254.0  248.020004  248.770004  213.306046
#
#       Volume  MA_30  MA_40  MA_50   ...    SO%d_30  SO%d_40  SO%d_50  \
# 0  6417705.0    NaN    NaN    NaN   ...        NaN      NaN      NaN
#
#        SO%k  Momentum_30  Momentum_40  Momentum_50  CCI_30  CCI_40  CCI_50
# 0  0.125418          NaN          NaN          NaN     NaN     NaN     NaN
#
# [1 rows x 35 columns]

# %%
df10 = ti.chaikin_oscillator(df93)

# %%
df10.head(1)
# Out:
#          Date        Open   High         Low       Close   Adj Close  \
# 0  2013-04-04  253.199997  254.0  248.020004  248.770004  213.306046
#
#       Volume  MA_30  MA_40  MA_50   ...     SO%d_40  SO%d_50      SO%k  \
# 0  6417705.0    NaN    NaN    NaN   ...         NaN      NaN  0.125418
#
#    Momentum_30  Momentum_40  Momentum_50  CCI_30  CCI_40  CCI_50  Chaikin
# 0          NaN          NaN          NaN     NaN     NaN     NaN      NaN
#
# [1 rows x 36 columns]

# %%
df101 = ti.donchian_channel(df10,n1)
df102 = ti.donchian_channel(df101,n2)
df103 = ti.donchian_channel(df102,n3)

# %%
df103.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2013-04-04  253.199997  254.000000  248.020004  248.770004  213.306046
# 1  2013-04-05  248.089996  249.869995  243.440002  245.910004  210.853775
# 2  2013-04-08  245.300003  247.600006  239.600006  240.639999  206.335022
# 3  2013-04-09  242.070007  247.960007  239.759995  240.639999  206.335022
# 4  2013-04-10  242.960007  248.570007  240.000000  247.860001  212.525757
#
#        Volume  MA_30  MA_40  MA_50     ...       Momentum_30  Momentum_40  \
# 0   6417705.0    NaN    NaN    NaN     ...               NaN          NaN
# 1   6484050.0    NaN    NaN    NaN     ...               NaN          NaN
# 2   4864420.0    NaN    NaN    NaN     ...               NaN          NaN
# 3   7490495.0    NaN    NaN    NaN     ...               NaN          NaN
# 4  10046765.0    NaN    NaN    NaN     ...               NaN          NaN
#
#    Momentum_50  CCI_30  CCI_40  CCI_50  Chaikin  Donchian_30  Donchian_40  \
# 0          NaN     NaN     NaN     NaN      NaN          NaN          NaN
# 1          NaN     NaN     NaN     NaN      NaN          NaN          NaN
# 2          NaN     NaN     NaN     NaN      NaN          NaN          NaN
# 3          NaN     NaN     NaN     NaN      NaN          NaN          NaN
# 4          NaN     NaN     NaN     NaN      NaN          NaN          NaN
#
#    Donchian_50
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 39 columns]

# %%
df111 = ti.rate_of_change(df103, n1)
df112 = ti.rate_of_change(df111, n2)
df113 = ti.rate_of_change(df112, n3)

# %%
df113.head(1)
# Out:
#          Date        Open   High         Low       Close   Adj Close  \
# 0  2013-04-04  253.199997  254.0  248.020004  248.770004  213.306046
#
#       Volume  MA_30  MA_40  MA_50   ...    CCI_30  CCI_40  CCI_50  Chaikin  \
# 0  6417705.0    NaN    NaN    NaN   ...       NaN     NaN     NaN      NaN
#
#    Donchian_30  Donchian_40  Donchian_50  ROC_30  ROC_40  ROC_50
# 0          NaN          NaN          NaN     NaN     NaN     NaN
#
# [1 rows x 42 columns]

# %%
df113 = ti.ultimate_oscillator(df113)

# %%
df121 = ti.williamsR(df113,n1)
df122 = ti.williamsR(df121,n2)
df123 = ti.williamsR(df122,n3)

# %%
df123.head(1)
# Out:
#          Date        Open   High         Low       Close   Adj Close  \
# 0  2013-04-04  253.199997  254.0  248.020004  248.770004  213.306046
#
#       Volume  MA_30  MA_40  MA_50      ...       Donchian_30  Donchian_40  \
# 0  6417705.0    NaN    NaN    NaN      ...               NaN          NaN
#
#    Donchian_50  ROC_30  ROC_40  ROC_50  Ultimate_Osc  WilliamsR_30  \
# 0          NaN     NaN     NaN     NaN           NaN           NaN
#
#    WilliamsR_40  WilliamsR_50
# 0           NaN           NaN
#
# [1 rows x 46 columns]

# %%
df131 = ti.aroon_oscillator(df123,n1)
df132 = ti.aroon_oscillator(df131,n2)
df133 = ti.aroon_oscillator(df132,n3)

# %%
df133.head(1)
# Out:
#          Date        Open   High         Low       Close   Adj Close  \
# 0  2013-04-04  253.199997  254.0  248.020004  248.770004  213.306046
#
#       Volume  MA_30  MA_40  MA_50  ...    ROC_30  ROC_40  ROC_50  \
# 0  6417705.0    NaN    NaN    NaN  ...       NaN     NaN     NaN
#
#    Ultimate_Osc  WilliamsR_30  WilliamsR_40  WilliamsR_50  AO_30  AO_40  AO_50
# 0           NaN           NaN           NaN           NaN    NaN    NaN    NaN
#
# [1 rows x 49 columns]

# %%
df133.shape
# Out:
# (1232, 49)

# %%
df133[48:].head(5)
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 48  2013-06-14  256.839996  262.079987  256.359985  259.600006  222.592148
# 49  2013-06-17  260.420013  264.209991  253.809998  263.209991  225.687515
# 50  2013-06-18  262.350006  262.940002  256.799988  257.320007  220.637161
# 51  2013-06-19  257.390015  257.899994  253.399994  257.010010  220.371384
# 52  2013-06-20  252.800003  253.199997  246.399994  247.960007  212.611511
#
#        Volume       MA_30      MA_40     MA_50  ...      ROC_30    ROC_40  \
# 48  9145290.0  287.645667  288.94025       NaN  ...   -0.110807 -0.057508
# 49  9148855.0  286.687666  288.63450  281.5886  ...   -0.124938 -0.079299
# 50  7215030.0  285.238666  287.92050  281.7596  ...   -0.136336 -0.107241
# 51  7633795.0  283.874333  287.14000  281.9816  ...   -0.116288 -0.110569
# 52  9339930.0  282.445334  286.11500  282.1280  ...   -0.156541 -0.175336
#
#       ROC_50  Ultimate_Osc  WilliamsR_30  WilliamsR_40  WilliamsR_50  \
# 48       NaN      2.781913    -86.119645    -86.119645           NaN
# 49  0.058046      2.889545    -79.948732    -79.948732    -66.453562
# 50  0.046399      2.854352    -90.017078    -90.017078    -74.822393
# 51  0.068027      3.158435    -90.546987    -90.546987    -75.262855
# 52  0.030419      2.989314    -97.546378    -97.546378    -88.322401
#
#         AO_30  AO_40  AO_50
# 48 -60.000000  -45.0    NaN
# 49 -60.000000  -45.0    NaN
# 50 -60.000000  -45.0   54.0
# 51 -60.000000  -45.0   54.0
# 52 -76.666667  -57.5   54.0
#
# [5 rows x 49 columns]

# %% [markdown]
# #### Computing percentage change/ percentage return price for target column

# %%
df133['PCT_price'] = df133['Close'].pct_change(periods=30)

# %%
df133.head(3)
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2013-04-04  253.199997  254.000000  248.020004  248.770004  213.306046
# 1  2013-04-05  248.089996  249.869995  243.440002  245.910004  210.853775
# 2  2013-04-08  245.300003  247.600006  239.600006  240.639999  206.335022
#
#       Volume  MA_30  MA_40  MA_50    ...      ROC_40  ROC_50  Ultimate_Osc  \
# 0  6417705.0    NaN    NaN    NaN    ...         NaN     NaN           NaN
# 1  6484050.0    NaN    NaN    NaN    ...         NaN     NaN           NaN
# 2  4864420.0    NaN    NaN    NaN    ...         NaN     NaN           NaN
#
#    WilliamsR_30  WilliamsR_40  WilliamsR_50  AO_30  AO_40  AO_50  PCT_price
# 0           NaN           NaN           NaN    NaN    NaN    NaN        NaN
# 1           NaN           NaN           NaN    NaN    NaN    NaN        NaN
# 2           NaN           NaN           NaN    NaN    NaN    NaN        NaN
#
# [3 rows x 50 columns]

# %%
df_raw_features = df133[49:]                             # avoid NaN rows

# %% [markdown]
# Stocks grow at a compounded rate and hence follow lognormal distribution.
# Lognormal distribution is extremely useful for stock prices as long as the growth factor is assumed to be normally distributed.

# %%
column_names = df_raw_features.columns

# %%
df_raw_features.head()
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 49  2013-06-17  260.420013  264.209991  253.809998  263.209991  225.687515
# 50  2013-06-18  262.350006  262.940002  256.799988  257.320007  220.637161
# 51  2013-06-19  257.390015  257.899994  253.399994  257.010010  220.371384
# 52  2013-06-20  252.800003  253.199997  246.399994  247.960007  212.611511
# 53  2013-06-21  245.809998  253.889999  244.789993  251.940002  216.024139
#
#         Volume       MA_30     MA_40     MA_50    ...        ROC_40    ROC_50  \
# 49   9148855.0  286.687666  288.6345  281.5886    ...     -0.079299  0.058046
# 50   7215030.0  285.238666  287.9205  281.7596    ...     -0.107241  0.046399
# 51   7633795.0  283.874333  287.1400  281.9816    ...     -0.110569  0.068027
# 52   9339930.0  282.445334  286.1150  282.1280    ...     -0.175336  0.030419
# 53  11567800.0  281.044000  284.8965  282.3540    ...     -0.152488  0.016461
#
#     Ultimate_Osc  WilliamsR_30  WilliamsR_40  WilliamsR_50      AO_30  AO_40  \
# 49      2.889545    -79.948732    -79.948732    -66.453562 -60.000000  -45.0
# 50      2.854352    -90.017078    -90.017078    -74.822393 -60.000000  -45.0
# 51      3.158435    -90.546987    -90.546987    -75.262855 -60.000000  -45.0
# 52      2.989314    -97.546378    -97.546378    -88.322401 -76.666667  -57.5
# 53      3.481562    -89.032049    -89.032049    -82.937982 -80.000000  -60.0
#
#     AO_50  PCT_price
# 49    NaN  -0.098442
# 50   54.0  -0.144519
# 51   54.0  -0.137377
# 52   54.0  -0.147406
# 53   52.0  -0.143003
#
# [5 rows x 50 columns]

# %%
df_raw_features.tail()
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 1227  2018-03-27  512.299988  522.549988  509.049988  512.200012  512.200012
# 1228  2018-03-28  512.900024  512.900024  501.600006  510.500000  510.500000
# 1229  2018-04-02  510.500000  510.500000  492.200012  499.049988  499.049988
# 1230  2018-04-03  494.000000  506.000000  493.700012  501.549988  501.549988
# 1231  2018-04-04  504.500000  504.500000  490.250000  492.250000  492.250000
#
#           Volume       MA_30       MA_40       MA_50    ...        ROC_40  \
# 1227   6423140.0  527.780002  539.982500  549.881999    ...     -0.154157
# 1228  10980960.0  525.990001  537.606251  548.989999    ...     -0.140211
# 1229   7120498.0  524.495000  535.238750  547.759999    ...     -0.159282
# 1230   6053789.0  523.089999  532.937501  546.526999    ...     -0.153931
# 1231   6047813.0  521.570000  530.423751  544.667999    ...     -0.128607
#
#         ROC_50  Ultimate_Osc  WilliamsR_30  WilliamsR_40  WilliamsR_50  \
# 1227 -0.077283      3.200959    -76.648348    -86.475737    -87.160117
# 1228 -0.089287      3.411686    -78.343955    -86.672483    -88.444115
# 1229 -0.113903      3.217038    -89.057542    -94.185079    -94.940932
# 1230 -0.142943      3.260615    -84.967887    -92.062838    -93.094551
# 1231 -0.158259      3.085564    -96.882308    -97.949769    -98.543866
#
#            AO_30  AO_40  AO_50  PCT_price
# 1227  -93.333333  -95.0  -82.0  -0.081338
# 1228  -93.333333  -95.0  -82.0  -0.095179
# 1229 -100.000000  -95.0  -88.0  -0.082460
# 1230  -96.666667  -95.0  -88.0  -0.077524
# 1231  -80.000000 -100.0  -92.0  -0.084782
#
# [5 rows x 50 columns]

# %% [markdown]
# Calculating technical indicator features from lagging features result in zero-values in the initial rows till the specified lagged period. Replacing infinite and zero values with NaN.

# %%
df_to_fillna = df_raw_features.drop('Date',axis=1)
df_to_fillna.replace([np.inf, -np.inf,0], np.nan,inplace=True)

# %%
df_to_fillna.head(1)
# Out:
#           Open        High         Low       Close   Adj Close     Volume  \
# 49  260.420013  264.209991  253.809998  263.209991  225.687515  9148855.0
#
#          MA_30     MA_40     MA_50      EMA_30    ...        ROC_40    ROC_50  \
# 49  286.687666  288.6345  281.5886  279.149545    ...     -0.079299  0.058046
#
#     Ultimate_Osc  WilliamsR_30  WilliamsR_40  WilliamsR_50  AO_30  AO_40  \
# 49      2.889545    -79.948732    -79.948732    -66.453562  -60.0  -45.0
#
#     AO_50  PCT_price
# 49    NaN  -0.098442
#
# [1 rows x 49 columns]

# %% [markdown]
# Filling NaN values with the column average value.

# %%
df_to_normalize = df_to_fillna.fillna(df_to_fillna.mean())

# %%
df_to_normalize.head(2)
# Out:
#           Open        High         Low       Close   Adj Close     Volume  \
# 49  260.420013  264.209991  253.809998  263.209991  225.687515  9148855.0
# 50  262.350006  262.940002  256.799988  257.320007  220.637161  7215030.0
#
#          MA_30     MA_40     MA_50      EMA_30    ...        ROC_40    ROC_50  \
# 49  286.687666  288.6345  281.5886  279.149545    ...     -0.079299  0.058046
# 50  285.238666  287.9205  281.7596  277.692626    ...     -0.107241  0.046399
#
#     Ultimate_Osc  WilliamsR_30  WilliamsR_40  WilliamsR_50  AO_30  AO_40  \
# 49      2.889545    -79.948732    -79.948732    -66.453562  -60.0  -45.0
# 50      2.854352    -90.017078    -90.017078    -74.822393  -60.0  -45.0
#
#        AO_50  PCT_price
# 49  15.79357  -0.098442
# 50  54.00000  -0.144519
#
# [2 rows x 49 columns]

# %%
df_to_normalize.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1183.000000  1183.000000  1183.000000  1183.000000  1183.000000
# mean    449.128183   454.966578   442.921732   448.808014   438.766974
# std     115.296031   116.183285   114.007365   115.007147   119.532178
# min     156.559998   163.399994   152.679993   156.570007   144.533203
# 25%     389.300003   395.425003   383.845001   390.074997   379.239059
# 50%     489.700012   495.700012   483.500000   488.500000   481.719971
# 75%     534.000000   539.400024   525.524994   533.275024   528.763733
# max     650.900024   654.900024   628.700012   647.549988   630.240906
#
#              Volume        MA_30        MA_40        MA_50       EMA_30  \
# count  1.183000e+03  1183.000000  1183.000000  1183.000000  1183.000000
# mean   8.992257e+06   445.933125   444.926688   443.806229   445.832184
# std    7.965878e+06   114.770176   114.581246   114.346329   113.954563
# min    1.238680e+06   195.272666   200.370750   204.046200   198.085098
# 25%    4.973424e+06   390.293503   387.906002   385.049601   388.573434
# 50%    7.003729e+06   492.994999   491.899998   489.478002   492.156369
# 75%    1.040717e+07   533.168335   531.754375   529.986502   533.150345
# max    1.205419e+08   593.855001   583.685001   577.908999   590.544317
#
#           ...            ROC_40       ROC_50  Ultimate_Osc  WilliamsR_30  \
# count     ...       1183.000000  1183.000000   1183.000000   1183.000000
# mean      ...          0.028487     0.037989      3.458178    -45.009572
# std       ...          0.130800     0.145678      0.613085     30.095548
# min       ...         -0.374995    -0.370218      1.534229    -99.021402
# 25%       ...         -0.057982    -0.055036      3.002880    -71.716268
# 50%       ...          0.028776     0.030649      3.464519    -41.827662
# 75%       ...          0.107033     0.135459      3.903337    -17.399931
# max       ...          0.561857     0.456026      5.007196     -0.806018
#
#        WilliamsR_40  WilliamsR_50        AO_30        AO_40        AO_50  \
# count   1183.000000   1183.000000  1183.000000  1183.000000  1183.000000
# mean     -44.287175    -43.946529    10.814314    13.901099    15.793570
# std       30.781354     30.991041    62.324195    63.383578    63.169297
# min      -99.176090    -99.176090  -100.000000  -100.000000  -100.000000
# 25%      -71.459744    -72.150772   -43.333333   -47.500000   -52.000000
# 50%      -39.652874    -39.629630    26.666667    37.500000    34.000000
# 75%      -15.263862    -14.648627    66.666667    67.500000    68.000000
# max       -0.676061     -0.656780   100.000000   100.000000   100.000000
#
#          PCT_price
# count  1183.000000
# mean      0.021391
# std       0.111731
# min      -0.359806
# 25%      -0.049250
# 50%       0.021837
# 75%       0.086853
# max       0.476911
#
# [8 rows x 49 columns]

# %% [markdown]
# scaling the features to bring the values in the range (0,1)

# %%
target_price = df_to_normalize['PCT_price'][30:]

# %%
training_set = df_to_normalize.drop('PCT_price',axis=1)

# %%
target_price = target_price.reset_index()

# %%
target_price.index
# Out:
# RangeIndex(start=0, stop=1153, step=1)

# %%
training_set.reset_index(inplace=True)

# %%
final_raw_features = pd.concat([training_set,target_price],axis=1)

# %%
final_raw_features.drop('index',axis=1,inplace=True)

# %%
final_raw_features
# Out:
#             Open        High         Low       Close   Adj Close      Volume  \
# 0     260.420013  264.209991  253.809998  263.209991  225.687515   9148855.0
# 1     262.350006  262.940002  256.799988  257.320007  220.637161   7215030.0
# 2     257.390015  257.899994  253.399994  257.010010  220.371384   7633795.0
# 3     252.800003  253.199997  246.399994  247.960007  212.611511   9339930.0
# 4     245.809998  253.889999  244.789993  251.940002  216.024139  11567800.0
# 5     249.860001  251.759995  246.869995  248.610001  213.168839   8864770.0
# 6     250.199997  250.800003  241.580002  246.289993  211.179581  17111600.0
# 7     247.220001  252.839996  247.220001  249.679993  214.086288  13302520.0
# 8     252.800003  257.000000  252.740005  255.009995  218.656479  11566105.0
# 9     258.399994  266.399994  257.500000  265.040009  227.256653   7250955.0
# 10    264.799988  270.779999  264.010010  269.760010  231.303757   5323995.0
# 11    268.420013  270.980011  260.929993  261.700012  224.392792   5683025.0
# 12    258.290009  260.410004  254.220001  255.570007  219.136642   6367035.0
# 13    256.420013  258.600006  251.820007  252.990005  216.924454   9497150.0
# 14    254.360001  260.279999  253.800003  257.609985  237.805466   5785940.0
# 15    255.800003  255.800003  249.199997  250.509995  231.251297  10780235.0
# 16    253.000000  255.460007  252.000000  252.869995  233.429871   4614270.0
# 17    253.800003  256.299988  249.970001  251.350006  232.026749   5341890.0
# 18    256.200012  259.980011  255.449997  257.549988  237.750061   4593290.0
# 19    259.200012  259.700012  254.199997  258.309998  238.451660   5287195.0
# 20    258.399994  262.989990  256.489990  261.779999  241.654892   5449990.0
# 21    254.000000  254.000000  245.210007  246.169998  227.244949   9493130.0
# 22    247.190002  247.199997  235.529999  238.740005  220.386169  17944220.0
# 23    241.350006  249.520004  231.619995  247.639999  228.601944  28548405.0
# 24    250.000000  250.600006  237.000000  238.380005  220.053833  18642230.0
# 25    238.800003  242.160004  235.690002  240.020004  221.567764   6446280.0
# 26    243.960007  243.960007  239.410004  240.570007  222.075470   5451370.0
# 27    234.570007  234.570007  224.000000  225.029999  207.730148  14788645.0
# 28    222.809998  228.960007  222.399994  225.449997  208.117859  21479325.0
# 28    -56.666667 -100.0 -96.00000  -0.114393
# 29    -60.000000  -95.0 -98.00000  -0.070248
# ...          ...    ...       ...        ...
# 1153  -56.666667  -42.5 -34.00000        NaN
# 1154  -56.666667  -42.5 -34.00000        NaN
# 1155  -63.333333  -47.5 -38.00000        NaN
# 1156  -63.333333  -47.5 -38.00000        NaN
# 1157  -63.333333  -47.5 -38.00000        NaN
# 1158  -63.333333  -47.5 -38.00000        NaN
# 1159  -63.333333  -47.5 -38.00000        NaN
# 1160  -80.000000  -60.0 -48.00000        NaN
# 1161  -80.000000  -60.0 -48.00000        NaN
# 1162  -80.000000  -60.0 -48.00000        NaN
# 1163  -90.000000  -67.5 -54.00000        NaN
# 1164  -93.333333  -70.0 -56.00000        NaN
# 1165  -96.666667  -72.5 -58.00000        NaN
# 1166 -100.000000  -75.0 -60.00000        NaN
# 1167  -96.666667  -75.0 -60.00000        NaN
# 1168  -90.000000  -75.0 -60.00000        NaN
# 1169  -90.000000  -75.0 -60.00000        NaN
# 1170  -80.000000  -75.0 -60.00000        NaN
# 1171  -80.000000  -75.0 -60.00000        NaN
# 1172  -80.000000  -75.0 -60.00000        NaN
# 1173  -76.666667  -75.0 -60.00000        NaN
# 1174  -70.000000  -75.0 -60.00000        NaN
# 1175  -70.000000  -75.0 -60.00000        NaN
# 1176  -96.666667 -100.0 -80.00000        NaN
# 1177 -100.000000 -100.0 -82.00000        NaN
# 1178  -93.333333  -95.0 -82.00000        NaN
# 1179  -93.333333  -95.0 -82.00000        NaN
# 1180 -100.000000  -95.0 -88.00000        NaN
# 1181  -96.666667  -95.0 -88.00000        NaN
# 1182  -80.000000 -100.0 -92.00000        NaN
#
# [1183 rows x 49 columns]

# %%
final_raw_features.columns
# Out:
# Index([u'Open', u'High', u'Low', u'Close', u'Adj Close', u'Volume', u'MA_30',
#        u'MA_40', u'MA_50', u'EMA_30', u'EMA_40', u'EMA_50', u'MACD_12_26',
#        u'MACDsign_12_26', u'MACDdiff_12_26', u'RSI_30', u'RSI_40', u'RSI_50',
#        u'BollingerB_30', u'Bollinger%b_30', u'BollingerB_40',
#        u'Bollinger%b_40', u'BollingerB_50', u'Bollinger%b_50', u'SO%d_30',
#        u'SO%d_40', u'SO%d_50', u'SO%k', u'Momentum_30', u'Momentum_40',
#        u'Momentum_50', u'CCI_30', u'CCI_40', u'CCI_50', u'Chaikin',
#        u'Donchian_30', u'Donchian_40', u'Donchian_50', u'ROC_30', u'ROC_40',
#        u'ROC_50', u'Ultimate_Osc', u'WilliamsR_30', u'WilliamsR_40',
#        u'WilliamsR_50', u'AO_30', u'AO_40', u'AO_50', u'PCT_price'],
#       dtype='object')

# %%
min_max_scaler = MinMaxScaler()

# %%
scaled_inp_features = min_max_scaler.fit_transform(final_raw_features.drop('PCT_price',axis=1))

# %%
combined_df = pd.DataFrame(scaled_inp_features).join(final_raw_features['PCT_price'])

# %%
combined_df.columns = final_raw_features.columns

# %%
combined_df1 = df_raw_features.Date.reset_index().join(combined_df).drop('index',axis=1)

# %%
combined_df1.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close    Volume  \
# 0  2013-06-17  0.210098  0.205107  0.212449  0.217198   0.167085  0.066303
# 1  2013-06-18  0.214003  0.202523  0.218730  0.205202   0.156687  0.050094
# 2  2013-06-19  0.203969  0.192269  0.211588  0.204570   0.156140  0.053604
# 3  2013-06-20  0.194684  0.182706  0.196882  0.186138   0.140163  0.067905
# 4  2013-06-21  0.180544  0.184110  0.193500  0.194244   0.147189  0.086579
#
#       MA_30     MA_40     MA_50    ...        ROC_40    ROC_50  Ultimate_Osc  \
# 0  0.229350  0.230265  0.207409    ...      0.315627  0.518326      0.390247
# 1  0.225715  0.228402  0.207866    ...      0.285802  0.504230      0.380114
# 2  0.222292  0.226366  0.208460    ...      0.282250  0.530406      0.467671
# 3  0.218707  0.223692  0.208851    ...      0.213117  0.484890      0.418975
# 4  0.215191  0.220513  0.209456    ...      0.237505  0.467996      0.560711
#
#    WilliamsR_30  WilliamsR_40  WilliamsR_50     AO_30   AO_40     AO_50  \
# 0      0.194192      0.195202      0.332143  0.200000  0.2750  0.578968
# 1      0.091679      0.092985      0.247197  0.200000  0.2750  0.770000
# 2      0.086284      0.087605      0.242726  0.200000  0.2750  0.770000
# 3      0.015018      0.016545      0.110168  0.116667  0.2125  0.770000
# 4      0.101709      0.102985      0.164822  0.100000  0.2000  0.760000
#
#    PCT_price
# 0  -0.165495
# 1  -0.150474
# 2  -0.194934
# 3  -0.124214
# 4  -0.124236
#
# [5 rows x 50 columns]

# %%
combined_df1.to_csv('scaled_feature_set_AXISBANK.csv',index=False)

# %%
feature_set = pd.read_csv("scaled_feature_set_AXISBANK.csv",parse_dates=True)
feature_set.index = pd.to_datetime(feature_set.Date, format='%Y-%m-%d')
feature_set.drop('Date',axis=1,inplace=True)

# %%
feature_set.shape
# Out:
# (1183, 49)

# %%
feature_set[1152:].head()
# Out:
#                 Open      High       Low     Close  Adj Close    Volume  \
# Date
# 2018-02-16  0.789922  0.783723  0.803160  0.776569   0.809781  0.022395
# 2018-02-19  0.771311  0.776297  0.787404  0.782069   0.815340  0.025255
# 2018-02-20  0.779706  0.782604  0.791395  0.764043   0.797119  0.018076
# 2018-02-21  0.763523  0.763174  0.780892  0.772394   0.805560  0.028496
# 2018-02-22  0.761500  0.753510  0.787404  0.761090   0.794134  0.055067
#
#                MA_30     MA_40     MA_50    EMA_30    ...        ROC_40  \
# Date                                                  ...
# 2018-02-16  0.950671  0.963561  0.963166  0.939784    ...      0.368220
# 2018-02-19  0.949053  0.962651  0.963703  0.935450    ...      0.383938
# 2018-02-20  0.946414  0.961526  0.963578  0.929941    ...      0.358046
# 2018-02-21  0.943935  0.960365  0.963219  0.925462    ...      0.363345
# 2018-02-22  0.941003  0.958751  0.962425  0.920359    ...      0.353406
#
#               ROC_50  Ultimate_Osc  WilliamsR_30  WilliamsR_40  WilliamsR_50  \
# Date
# 2018-02-16  0.464842      0.330482      0.058796      0.060196      0.081805
# 2018-02-19  0.462804      0.447403      0.122775      0.123990      0.123966
# 2018-02-20  0.423979      0.378158      0.032757      0.034233      0.034226
# 2018-02-21  0.427425      0.439840      0.102508      0.103782      0.103762
# 2018-02-22  0.429310      0.416433      0.047752      0.049184      0.049175
#
#                AO_30   AO_40  AO_50  PCT_price
# Date
# 2018-02-16  0.250000  0.3125   0.82  -0.084782
# 2018-02-19  0.216667  0.2875   0.33        NaN
# 2018-02-20  0.216667  0.2875   0.33        NaN
# 2018-02-21  0.183333  0.2625   0.31        NaN
# 2018-02-22  0.183333  0.2625   0.31        NaN
#
# [5 rows x 49 columns]

# %%
x_train = feature_set.drop('PCT_price',axis=1)[:1153]
x_test = feature_set['2018-04-04':].drop('PCT_price',axis=1)
x_test
# Out:
#                 Open      High       Low     Close  Adj Close   Volume  \
# Date
# 2018-04-04  0.703848  0.693998  0.709151  0.683694   0.715897  0.04031
#
#                MA_30     MA_40     MA_50    EMA_30  ...      ROC_30    ROC_40  \
# Date                                                ...
# 2018-04-04  0.818645  0.861051  0.911088  0.826419  ...    0.326902  0.262996
#
#               ROC_50  Ultimate_Osc  WilliamsR_30  WilliamsR_40  WilliamsR_50  \
# Date
# 2018-04-04  0.256533      0.446689       0.02178       0.01245      0.006417
#
#             AO_30  AO_40  AO_50
# Date
# 2018-04-04    0.1    0.0   0.04
#
# [1 rows x 48 columns]

# %%
min_max_scaler = MinMaxScaler()                                        
min_max_scaler.fit(feature_set[['PCT_price']][:1153])                  # fitting the scaler to the target of training data
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
y = min_max_scaler.transform(feature_set[['PCT_price']][:1153])        # transforming target of training data
y_train = pd.Series(y.reshape(y.shape[0],))
y_train.head()
# Out:
# 0    0.232230
# 1    0.250182
# 2    0.197046
# 3    0.281567
# 4    0.281541
# dtype: float64

# %% [markdown]
# Using LightGBM and treating this as a regression problem.

# %%
Train_data = lgb.Dataset(x_train,label=y_train)

# %%
params = {
    'task': 'train',
    'boosting_type': 'gbdt',
    'objective': 'regression',
    'metric': {'l2', 'auc'},
    'max_depth':5,
    'learning_rate': 0.1,
    'feature_fraction': 0.9,
    'bagging_fraction': 0.8,
    'bagging_freq': 5,
    'verbose': 0
}

num_round=60

# %% [markdown]
# #### Performing Bagging

# %%
PredictionsList = []

for i in np.arange(2,22):
    params['feature_fraction_seed'] = i
    # %time lgbm=lgb.train(params,Train_data,num_round,verbose_eval=False)

    lgb_predictions = lgbm.predict(x_test)
    p_len = len(lgb_predictions)
    predictions = min_max_scaler.inverse_transform(lgb_predictions.reshape(len(lgb_predictions),1)).reshape(p_len,)
    

    PredictionsList.append(predictions)
# Out:
# Wall time: 62 ms
# Wall time: 50 ms
# Wall time: 32 ms
# Wall time: 16 ms
# Wall time: 34 ms
# Wall time: 51 ms
# Wall time: 67 ms
# Wall time: 31 ms
# Wall time: 32 ms
# Wall time: 32 ms
# Wall time: 31 ms
# Wall time: 31 ms
# Wall time: 15 ms
# Wall time: 29 ms
# Wall time: 16 ms
# Wall time: 31 ms
# Wall time: 32 ms
# Wall time: 31 ms
# Wall time: 31 ms
# Wall time: 41 ms

# %%
Predictions_agg = [sum(n)/len(n) for n in zip(*PredictionsList)];
aggr_series  = pd.Series(Predictions_agg,name='Predicted Close',index=x_test.index)

# %%
aggr_series
# Out:
# Date
# 2018-04-04   -0.004086
# Name: Predicted Close, dtype: float64
